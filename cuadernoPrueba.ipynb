# %%
def primo(n):
    for i in range(2,n):
        if n%i == 0:
            return False
    return True

# %%
for i in [23, 7, 8, 9, 13]:
    print(primo(i), end = ' ')
# Out:
# True True False False True
